# %%
#Importing important Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### importing dataset

# %%
data = pd.read_csv('heart_disease_dataset.csv')

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#   ca thal  num
# 0  0    6    0
# 1  3    3    2
# 2  2    7    1
# 3  0    3    0
# 4  0    3    0

# %%
data.shape
# Out:
# (303, 14)

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %% [markdown]
# #### There are total 14 features/columns.
#
# age: person age in years
#
# sex: person sex (1 = male, 0 = female)
#
# cp: The chest pain experienced (Value 1: typical angina, Value 2: atypical angina, Value 3: non-anginal pain, Value 4: asymptomatic)
#
# trestbps: person's resting blood pressure (mm Hg on admission to the hospital)
#
# chol: person cholesterol measurement in mg/dl
#
# fbs: person's fasting blood sugar (> 120 mg/dl, 1 = true; 0 = false)
#
# restecg: Resting electrocardiographic measurement (0 = normal, 1 = having ST-T wave abnormality, 2 = showing probable or definite left ventricular hypertrophy by Estes' criteria)
#
# thalach: The person's maximum heart rate achieved
#
# exang: Exercise induced angina (1 = yes; 0 = no)
#
# oldpeak: ST depression induced by exercise relative to rest
#
# slope: the slope of the peak exercise ST segment (Value 1: upsloping, Value 2: flat, Value 3: downsloping)
#
# ca: The number of major vessels (0-3)
#
# thal: A blood disorder called thalassemia (3 = normal; 6 = fixed defect; 7 = reversable defect)
#
# num: Heart disease (0 = no, 1 = yes)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    object
#  12  thal      303 non-null    object
#  13  num       303 non-null    int64
# dtypes: float64(1), int64(11), object(2)
# memory usage: 33.3+ KB

# %% [markdown]
# ##### Here all the columns have numerical data type except 'ca' and 'thal'.

# %%
data.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     50
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# num           5
# dtype: int64

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %% [markdown]
# ##### No null values present in the dataset.

# %%
data[['ca','thal']]
# Out:
#     ca thal
# 0    0    6
# 1    3    3
# 2    2    7
# 3    0    3
# 4    0    3
# ..  ..  ...
# 298  0    7
# 299  2    7
# 300  1    7
# 301  1    3
# 302  ?    3
#
# [303 rows x 2 columns]

# %% [markdown]
# ### Here we can observe there is an invalid data '?' present in 'ca' column.

# %%
data.iloc[266]
# Out:
# age          52
# sex           1
# cp            4
# trestbps    128
# chol        204
# fbs           1
# restecg       0
# thalach     156
# exang         1
# oldpeak     1.0
# slope         2
# ca            0
# thal          ?
# num           2
# Name: 266, dtype: object

# %% [markdown]
# ##### column 'thal' has also some invalid data i.e. '?' .

# %%
data['ca'].unique()
# Out:
# array(['0', '3', '2', '1', '?'], dtype=object)

# %%
data['thal'].unique()
# Out:
# array(['6', '3', '7', '?'], dtype=object)

# %%
mode_ca = data['ca'].mode()
mode_thal = data['thal'].mode()

# %%
mode_ca = int(mode_ca)
mode_thal = int(mode_thal)

# %%
data['ca'] = data['ca'].replace('?', mode_ca)
data['thal'] = data['thal'].replace('?', mode_thal)

# %% [markdown]
# ##### replaced '?' by the mode of 'ca' and 'thal' columns respectively.

# %%
data[['ca','thal']] = data[['ca','thal']].astype(int)

# %%
data['ca'].unique()
# Out:
# array([0, 3, 2, 1])

# %%
data['thal'].unique()
# Out:
# array([6, 3, 7])

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### There is no any duplicate value in the dataset.

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
data.groupby('num').size()
# Out:
# num
# 0    164
# 1     55
# 2     36
# 3     35
# 4     13
# dtype: int64

# %%
#Converting Numerical Data into Categorical Data

def heart_disease(value):
    if value==0:
        return 'Absence'
    elif value >= 1:
        return 'Presence'

# %%
#Applying converted data into our dataset with new column - heart_disease

data['heart_disease']=data['num'].apply(heart_disease)
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num heart_disease
# 0   0     6    0       Absence
# 1   3     3    2      Presence
# 2   2     7    1      Presence
# 3   0     3    0       Absence
# 4   0     3    0       Absence

# %%
h_d = data.groupby('heart_disease').size()
h_d
# Out:
# heart_disease
# Absence     164
# Presence    139
# dtype: int64

# %%
# percentage(%) of heart disease population

plt.pie(h_d, labels=['Absence','Presence'],  autopct='%0.0f%%')
plt.title('Heart Disease Population (%)', fontsize=20)
plt.show()

# %% [markdown]
# #### % of population having heart disease is lesser than population who doesn't have heart disease.

# %%
#Heatmap using Seaborn

plt.figure(figsize=(16,9))
sns.heatmap(data.corr(), annot=True, linewidth=3)
# Out:
# <AxesSubplot:>

# %%
#Countplot of Population Age 

plt.figure(figsize=(15,7))
sns.countplot(x='age', data=data)
plt.title('Population Age', fontsize=17)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.show()

# %% [markdown]
# #### Most number of person are from age 40-70.

# %%
min_age=data['age'].min()
max_age=data['age'].max()
mean_age=data['age'].mean()
print("Minimum Age =",min_age)
print("Maximum Age =",max_age)
print("Mean Age =",mean_age)
# Out:
# Minimum Age = 29
# Maximum Age = 77
# Mean Age = 54.43894389438944

# %% [markdown]
# ##### The average age of the population is 54 years.

# %%
Young_Ages=data[(data['age']>=29) & (data['age']<40)]
Middle_Ages=data[(data['age']>=40) & (data['age']<55)]
Elderly_Ages=data[(data['age']>55)]
print('Young Ages =',len(Young_Ages))
print('Middle Ages =',len(Middle_Ages))
print('Elderly Ages =',len(Elderly_Ages))
# Out:
# Young Ages = 15
# Middle Ages = 128
# Elderly Ages = 152

# %% [markdown]
# #### In the above cell I have divided the age into three age groups.

# %%
#Bar Plot of Age Category using MatplotLib and Seaborn

sns.barplot(x=['Young_Ages','Middle_Ages','Elderly_Ages'], y=[len(Young_Ages), len(Middle_Ages), len(Elderly_Ages)])
plt.title('Age Category', fontsize=17)
plt.xlabel('Age Group', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.show()

# %% [markdown]
# #### Most no. of persons belogs to either middle age group or elderly age group.

# %%
def gender(value):
    if value==1:
        return 'Male'
    elif value==0:
        return 'Female'
    
#converted sex column from numerical to categorical.

# %%
#creating new column as sex1

data['sex1']=data['sex'].apply(gender)
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num heart_disease    sex1
# 0   0     6    0       Absence    Male
# 1   3     3    2      Presence    Male
# 2   2     7    1      Presence    Male
# 3   0     3    0       Absence    Male
# 4   0     3    0       Absence  Female

# %%
def age_range(val):
    if val>=29 and val<40:
        return 'Young Age'
    elif val>=40 and val<55:
        return 'Middle Age'
    elif val>55:
        return 'Elder Age'

# %%
data['Age_Range']=data['age'].apply(age_range)
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num heart_disease    sex1   Age_Range
# 0   0     6    0       Absence    Male   Elder Age
# 1   3     3    2      Presence    Male   Elder Age
# 2   2     7    1      Presence    Male   Elder Age
# 3   0     3    0       Absence    Male   Young Age
# 4   0     3    0       Absence  Female  Middle Age

# %% [markdown]
# #### Converted num, sex and age column into categorical variable.

# %%
#Count Plot of Heart Disease Based On Age Category

sns.countplot(x='heart_disease', hue='Age_Range', data=data)
plt.title('Heart Disease By Age group', fontsize=15)
plt.xlabel('Heart Disease', fontsize=12)
plt.ylabel('Counts', fontsize=12)
plt.show()

# %% [markdown]
# #### Elder age people are mostly affected by heart disease.

# %%
#Count Plot Creation of Heart Disease Based on Gender

sns.countplot(x=data['heart_disease'], hue='sex1', data=data)
plt.title('Heart Disease By Gender',fontsize=15)
plt.xlabel('heart disease', fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.show()

# %% [markdown]
# #### Male population are more affected by heart disease incomparison to female population.

# %%
#Bar Plot of People Resting Blood Pressure in mm Hg.

sns.barplot(x='sex1', y='trestbps', data=data)
plt.title("Blood Pressure", fontsize=15)
plt.xlabel('Sex',fontsize=12)
plt.ylabel("People Resting Blood Pressure", fontsize=12)
plt.show()

# %% [markdown]
# #### Blood pressure rate is almost similar in males and females.

# %%
#Bar Plot of Heart Diseease by cholestrol

sns.barplot(x='heart_disease', y='chol', data=data, palette='inferno')
plt.title('Cholestrol by Heart Disease', fontsize=15)
plt.xlabel('Heart Disease', fontsize=12)
plt.ylabel('Cholestrol', fontsize=12)
plt.show()

# %% [markdown]
# #### Higher cholestrol level results increase in chances of heart disease.

# %%
#Plot of Blood Pressure by Heart Disease

sns.barplot(x='heart_disease', y='trestbps', data=data, palette='viridis_r')
plt.title('Blood Pressure by Heart Disease', fontsize=17)
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Blood Pressure', fontsize=15)
plt.show()

# %% [markdown]
# #### Higher blood pressure level results increase in chances of heart disease.

# %%
#Line Plot of Blood Pressure wrt Age

sns.lineplot(x='age', y='trestbps', data=data, color='red')
plt.title('Blood Pressure wrt Age', fontsize=15)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Blood Pressure', fontsize=12)
plt.show()

# %% [markdown]
# blood pressure started to increase from the age of 50 and continues the same pattern till the age of 70.

# %%
#Count Plot of Chest Pain by heart disease

sns.countplot(x=data['heart_disease'], hue='cp', data=data, order=['Presence','Absence'])
plt.title('Chest Pain Experienced', fontsize=15)
plt.xlabel('Heart Disease',fontsize=12)
plt.ylabel('Counts',fontsize=12)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %% [markdown]
# Here we can observe that person having asymptomatic chest pain have a higher chance of heart disease.

# %%
sns.countplot(x=data['sex1'], hue='cp', data=data)
plt.title('Gender wise chest pain', fontsize=15)
plt.xlabel('Sex', fontsize=12)
plt.ylabel('Counts', fontsize=12)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %% [markdown]
# we can see that higher number number of male population suffered from asymptomatic chest pain.

# %%
#Count Plot of Chest Pain Based On Age Category

sns.countplot(x=data['Age_Range'], hue='cp', data=data)
plt.title('Age Group wise Chest Pain', fontsize=15)
plt.xlabel('Age Category', fontsize=12)
plt.ylabel('Counts', fontsize=12)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %% [markdown]
#  There is very high number of Asymptomatic Pain in Elder people.

# %%
#Line Plot Cholestrol by Age

sns.lineplot(x='age', y='chol', data=data, color='brown')
plt.title('Cholestrol wrt Age', fontsize=15)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Cholestrol', fontsize=12)
plt.show()

# %% [markdown]
# we can observe that cholestrol level started to increase from the age of 40-70.

# %%
#Line Plot of Age wise ST Depression

sns.lineplot(x='age', y='oldpeak', data=data, color='black')
plt.title('ST Depression by Age', fontsize=15)
plt.xlabel('Age', fontsize=12)
plt.ylabel('ST depression', fontsize=12)
plt.show()

# %% [markdown]
# ST depression mostly increases in the age of 30-40.
#
# ST depression refers to a finding on hearts electrical activity, wherein the trace in the ST segment is abnormally low below the baseline.

# %%
#Bar Plot of ST depression wrt Heart Disease

sns.barplot(x='sex1', y='oldpeak', data=data)
plt.title('ST depression wrt Heart Disease', fontsize=15)
plt.xlabel('Sex', fontsize=13)
plt.ylabel('ST depression', fontsize=13)
plt.show()

# %% [markdown]
# Males are more prone to st depression than females.

# %%
#Bar Plot of Exercise With Angina by Heart Disease

sns.barplot(x='heart_disease', y='exang', data=data)
plt.title('Exercise With Angina VS Heart Disease', fontsize=15)
plt.xlabel('Heart Disease', fontsize=13)
plt.ylabel('Exercise With Angina', fontsize=13)
plt.show()

# %% [markdown]
# if a person suffer from Angina, he/she may be concerned that exercise will make him/her symptoms worse.

# %%
#Bar Plot of Exercise With Angina wrt Gender

sns.barplot(x='sex1', y='exang', data=data)
plt.title('Exercise With Angina wrt Gender', fontsize=15)
plt.xlabel('Sex', fontsize=12)
plt.ylabel('Exercise With Angina', fontsize=12)
plt.show()

# %% [markdown]
# Males have high Exercise Angina.
#
# A type of chest pain caused by reduced blood flow to the heart.

# %%
#Bar Plot of Fasting Blood Sugar wrt Gender

sns.barplot(y='fbs', x='sex1', data=data)
plt.title(' Fasting Blood Sugar wrt Gender', fontsize=15)
plt.xlabel('Sex', fontsize=12)
plt.ylabel('Fasting Blood Sugar', fontsize=13)
plt.show()

# %% [markdown]
# #### fasting blood sugar is more in males.
#
# ***Your fasting blood sugar level is the amount of sugar in your blood after you have gone without food for at least 8 hours. The normal fasting blood sugar level is less than 100 mg/dL. If your fasting blood sugar level is between 100 and 125 mg/dL, you have a condition called prediabetes. This means you are at high risk for developing diabetes. If your fasting blood sugar level is greater than 125 mg/dL, you have diabetes.

# %%
# Save the dataframe as a CSV file
data.to_csv('cleaned_data.csv', index=False)
